# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# In this notebook, we will clean the spotify dataset we will be using for our project. Please download the entire dataset here: https://www.kaggle.com/datasets/dhruvildave/spotify-charts **Please make sure to run 'convert_spotify_data.py' with correct paths in the method parameters before running this notebook**.
# That short script will only retain the years we acutally need for our project, in order to make the csv a lot smaller. (The dataset is too big, if we place the script in the notebook it takes a very long time to finish)

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)
data_raw = pd.read_csv("data/spotify_2020+.csv")

# %%
data_raw.head(10)
# Out:
#    Unnamed: 0      title  rank        date        artist    region   chart  \
# 0       19128    Ride It   146  2020-05-01        Regard   Bolivia  top200
# 1       19234     +Linda   147  2020-05-01         Dalex   Bolivia  top200
# 2       19287       Woah   148  2020-05-01      Lil Baby    Canada  top200
# 3       19390       25/8   105  2020-05-01     Bad Bunny     Chile  top200
# 4       19698       Keii    65  2020-05-01      Anuel AA  Colombia  top200
# 5       20166    Ride It    99  2020-05-01        Regard   Ecuador  top200
# 6       20427  Hei rakas    13  2020-05-01          BEHM   Finland  top200
# 7       28326     Tel Me   198  2020-05-01    Jul, Ninho    France  top200
# 8       28645      GOOBA     9  2020-06-01       6ix9ine   Austria  top200
# 9       28799         P2    69  2020-05-01  Lil Uzi Vert    Latvia  top200
#
#        trend     streams
# 0    MOVE_UP  1956.00000
# 1  MOVE_DOWN  1953.00000
# 2    MOVE_UP 35211.00000
# 3  MOVE_DOWN 31854.00000
# 4    MOVE_UP 16155.00000
# 5    MOVE_UP  5999.00000
# 6    MOVE_UP 28838.00000
# 7  MOVE_DOWN 33011.00000
# 8  MOVE_DOWN 22249.00000
# 9  MOVE_DOWN  1193.00000

# %% [markdown]
# First, lets see which columns contain missing values:

# %%
data_raw.isna().sum()
# Out:
# Unnamed: 0          0
# title               0
# rank                0
# date                0
# artist             18
# region              0
# chart               0
# trend               0
# streams       2510831
# dtype: int64

# %% [markdown]
# As evident, most missing values occur in the 'streams' column. We can drop this column since we wont need it in our analysis. We will also drop the 'Unnamed 0' column

# %%
data_no_streams = data_raw.drop(columns=["Unnamed: 0", "streams"],axis=1)

# %% [markdown]
# In this cell, we find out which entries have missing artist fields and inspect them:

# %%
artist_missing = data_no_streams.isna()
row_has_nan = artist_missing.any(axis=1)
rows_with_nan = artist_missing[row_has_nan]
indices_missing = rows_with_nan.index.values
data_no_streams.loc[indices_missing]
# Out:
#            title  rank        date artist region    chart          trend
# 7972060  NO GOOD    10  2020-07-13    NaN  Japan  viral50      NEW_ENTRY
# 7991853  NO GOOD    10  2020-07-14    NaN  Japan  viral50  SAME_POSITION
# 8015490  NO GOOD    10  2020-07-15    NaN  Japan  viral50  SAME_POSITION
# 8037120  NO GOOD    10  2020-07-16    NaN  Japan  viral50  SAME_POSITION
# 8053041  NO GOOD    10  2020-07-17    NaN  Japan  viral50  SAME_POSITION
# 8080759  NO GOOD    10  2020-07-18    NaN  Japan  viral50  SAME_POSITION
# 8102093  NO GOOD    10  2020-07-19    NaN  Japan  viral50  SAME_POSITION
# 8124034  NO GOOD    13  2020-07-20    NaN  Japan  viral50      MOVE_DOWN
# 8161478  NO GOOD    14  2020-07-21    NaN  Japan  viral50      MOVE_DOWN
# 8201506  NO GOOD    19  2020-07-22    NaN  Japan  viral50      MOVE_DOWN
# 8230055  NO GOOD    23  2020-07-23    NaN  Japan  viral50      MOVE_DOWN
# 8250277  NO GOOD    20  2020-07-24    NaN  Japan  viral50        MOVE_UP
# 8265792  NO GOOD    21  2020-07-25    NaN  Japan  viral50      MOVE_DOWN
# 8291153  NO GOOD    24  2020-07-26    NaN  Japan  viral50      MOVE_DOWN
# 8316674  NO GOOD    36  2020-07-27    NaN  Japan  viral50      MOVE_DOWN
# 8342345  NO GOOD    43  2020-07-28    NaN  Japan  viral50      MOVE_DOWN
# 8366949  NO GOOD    40  2020-07-29    NaN  Japan  viral50        MOVE_UP
# 8392084  NO GOOD    46  2020-07-30    NaN  Japan  viral50      MOVE_DOWN

# %% [markdown]
# All rows seem to use the song title 'NO GOOD'. Lets check if that title is used anywhere else or if this is showing a defect data entry:

# %%
mask = data_no_streams["title"].str.contains("NO GOOD")
data_no_streams[mask]
# Out:
#                               title  rank        date   artist region  \
# 3362515  NO GOOD (feat. MamboLosco)   146  2021-01-06  Malerba  Italy
# 7972060                     NO GOOD    10  2020-07-13      NaN  Japan
# 7991853                     NO GOOD    10  2020-07-14      NaN  Japan
# 8015490                     NO GOOD    10  2020-07-15      NaN  Japan
# 8037120                     NO GOOD    10  2020-07-16      NaN  Japan
# 8053041                     NO GOOD    10  2020-07-17      NaN  Japan
# 8080759                     NO GOOD    10  2020-07-18      NaN  Japan
# 8102093                     NO GOOD    10  2020-07-19      NaN  Japan
# 8124034                     NO GOOD    13  2020-07-20      NaN  Japan
# 8161478                     NO GOOD    14  2020-07-21      NaN  Japan
# 8201506                     NO GOOD    19  2020-07-22      NaN  Japan
# 8230055                     NO GOOD    23  2020-07-23      NaN  Japan
# 8250277                     NO GOOD    20  2020-07-24      NaN  Japan
# 8265792                     NO GOOD    21  2020-07-25      NaN  Japan
# 8291153                     NO GOOD    24  2020-07-26      NaN  Japan
# 8316674                     NO GOOD    36  2020-07-27      NaN  Japan
# 8342345                     NO GOOD    43  2020-07-28      NaN  Japan
# 8366949                     NO GOOD    40  2020-07-29      NaN  Japan
# 8392084                     NO GOOD    46  2020-07-30      NaN  Japan
#
#            chart          trend
# 3362515   top200      NEW_ENTRY
# 7972060  viral50      NEW_ENTRY
# 7991853  viral50  SAME_POSITION
# 8015490  viral50  SAME_POSITION
# 8037120  viral50  SAME_POSITION
# 8053041  viral50  SAME_POSITION
# 8080759  viral50  SAME_POSITION
# 8102093  viral50  SAME_POSITION
# 8124034  viral50      MOVE_DOWN
# 8161478  viral50      MOVE_DOWN
# 8201506  viral50      MOVE_DOWN
# 8230055  viral50      MOVE_DOWN
# 8250277  viral50        MOVE_UP
# 8265792  viral50      MOVE_DOWN
# 8291153  viral50      MOVE_DOWN
# 8316674  viral50      MOVE_DOWN
# 8342345  viral50      MOVE_DOWN
# 8366949  viral50        MOVE_UP
# 8392084  viral50      MOVE_DOWN

# %% [markdown]
# This could be an actual track name. We will therefore fill the Nan value with 'Unkown Artist' instead of deleting the rows:

# %%
data_no_streams["artist"].fillna(value="Unkown artist",inplace=True)

# %%
data_no_streams.isna().sum()# sanity check
# Out:
# title     0
# rank      0
# date      0
# artist    0
# region    0
# chart     0
# trend     0
# dtype: int64
